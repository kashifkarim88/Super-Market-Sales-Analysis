# %% [markdown]
# # Super Market Sales Data Analysis

# %% [markdown]
# ## About Dataset

# %% [markdown]
# This is explaining about the attributes that the data of Supermarket sales contains;
#
# - Invoice id: Computer generated sales slip invoice identification number
#
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# - City: Location of supercenters
#
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# - Gender: Gender type of customer
#
# - Product line: General item categorization groups — Electronic accessories, Fashion accessories, Food and beverages, Health   and beauty, Home and lifestyle, Sports and travel
#
# - Unit price: Price of each product in Dollars
#
# - Quantity: Number of products purchased by customer
#
# - Tax: 5% tax fee for customer buying
#
# - Total: Total price including tax
#
# - Date: Date of purchase (Record available from January 2019 to March 2019)
#
# - Time: Purchase time (10am to 9pm)
#
# - Payment: Payment used by customer for purchase (3 methods are available — Cash, Credit card and Ewallet)
#
# - COGS: Cost of goods sold
#
# - Gross margin percentage: Gross margin percentage
#
# - Gross income: Gross income
#
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# ### Lets Import Some Libraries & Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('supermarket_sales.csv')

# %%
df.head(4)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# ...

# %% [markdown]
# ### Describe The Statistics of Dataset

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# ### Show the Null Values

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
sns.countplot(x='Branch',data=df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %% [markdown]
# - We can see that Brach A has more Trafic of Customers.

# %%
sns.countplot(x='City',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %% [markdown]
# - The City Yangon has slighly more Customers than Naypyitaw and Mandaly.

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# - The Dataset contains about same number of male and females

# %%
sns.countplot(x='Customer type',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='count'>

# %% [markdown]
# - As we can see that most of the Females are 'Member Type' and Males are 'Normal Typed' Customers.

# %%
sns.countplot(x='City',hue='Customer type',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.countplot(x='City', hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %% [markdown]
# - The Graph illustraits that most of the Males are from "Yangon City". Where as most of the Females Customers are from "Naypyitaw City".

# %% [markdown]
# ### Lets Analyze the Product line

# %%
f , ax = plt.subplots(figsize =(15,7))
sns.countplot(x='Product line',data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# - It shows that most of the customers purchase Fashion accessories,Food and beverages and Electronic accessories

# %% [markdown]
# #### Lets see the product line purchases with Gender

# %%
f , ax = plt.subplots(figsize =(15,7))
sns.countplot(x='Product line',hue='Gender',data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %% [markdown]
# - it shows that mostly Female customers purchases "Fashion accessories, Food and Beverages,Sports and travel". Where Male Customers mostly purchase "Health and beauty" materials than females customers

# %% [markdown]
# ### Lets See the Payment Methods

# %%
sns.countplot(x='Payment',data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# - Most of the customers make purchases with Ewallet and Cash payment

# %%
sns.countplot(x='Payment',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# - Mostly Male customers holds Ewallet. where as Females make purchases with Cash payment and Credit Card

# %%
f,ax=plt.subplots(figsize=(12,8))
sns.countplot(x='Product line',hue='Payment',data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %% [markdown]
# - Customers pay Cash for purchasing Electronic accessories. However, for purchasing Fashion accessories and 'Home and Lifestyle' customer use Ewallet.

# %%
sns.relplot(x='Rating',y='gross income',data=df)

# %%
graph = sns.catplot(x='Product line', y='gross income',kind ='violin',inner=None,data=df,height=10)
sns.swarmplot(x='Product line', y='gross income',color='k',size = 3,data=df, ax=graph.ax)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='gross income'>

# %%
City_Grossincome = df.groupby('City')['gross income'].sum().plot.bar()

# %%
City_Grossincome = df.groupby(['City','Product line'])['gross income'].sum().plot.bar()

# %%
df_grouped_date = df.groupby('Date')['gross income'].count().plot.line()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Day'] = df['Date'].dt.day_name()

# %%
sns.countplot(x='Day',data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='count'>

# %%
df['Month'] = df['Date'].dt.month_name()

# %%
sns.countplot(x='Month',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
sns.catplot(y='Day',x='gross income',hue='Gender',kind='bar',data=df,height=9)

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Hour']=df['Time'].dt.hour

# %%
df['Hour'].unique()
# Out:
# array([13, 10, 20, 18, 14, 11, 17, 16, 19, 15, 12], dtype=int64)

# %%
sns.relplot(x='Hour',y='Quantity',kind='line',data=df)

# %%
plt.figure(figsize = (12,6))
sns.barplot(y = df['Product line'], x = df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Product line'>

# %%
sns.catplot(y='Product line', x='Quantity',kind='boxen',data=df)

# %%
data = df.groupby('Product line')['cogs'].sum()
data
# Out:
# Product line
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Food and beverages        53471.28
# Health and beauty         46851.18
# Home and lifestyle        51297.06
# Sports and travel         52497.93
# Name: cogs, dtype: float64

# %%
pie, ax = plt.subplots(figsize=[10,6])
explode = (0.01,0.01,0.4,0.01,0.01,0.01)
plt.pie(data,labels = data.keys(),startangle=90,autopct="%.1f%%",explode=explode)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2021-04-06 13:08:00      Ewallet  522.83                 4.761905
# ...

# %%
df_OneHot = pd.get_dummies(df)
df_OneHot.head()
# Out:
#    Unit price  Quantity   Tax 5%     Total       Date                Time  \
# 0       74.69         7  26.1415  548.9715 2019-01-05 2021-04-06 13:08:00
# 1       15.28         5   3.8200   80.2200 2019-03-08 2021-04-06 10:29:00
# 2       46.33         7  16.2155  340.5255 2019-03-03 2021-04-06 13:23:00
# 3       58.22         8  23.2880  489.0480 2019-01-27 2021-04-06 20:33:00
# 4       86.31         7  30.2085  634.3785 2019-02-08 2021-04-06 10:37:00
#
#      cogs  gross margin percentage  gross income  Rating  ...  Day_Friday  \
# 0  522.83                 4.761905       26.1415     9.1  ...           0
# 1   76.40                 4.761905        3.8200     9.6  ...           1
# 2  324.31                 4.761905       16.2155     7.4  ...           0
# 3  465.76                 4.761905       23.2880     8.4  ...           0
# 4  604.17                 4.761905       30.2085     5.3  ...           1
#
#    Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  Day_Tuesday  \
# ...

# %%
df=df_OneHot.copy()
df=df.drop(['Invoice ID','Day','Month','Time'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-491393ef7b35> in <module>
#       1 df=df_OneHot.copy()
# ----> 2 df=df.drop(['Invoice ID','Day','Month','Time'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# ...

# %% [markdown]
# ### Selecting X and Y Values

# %%
X= df.drop(['Time','gross income'],axis=1)
Y=df[['gross income']]
print(X.shape)
print(Y.shape)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.3, random_state=100,shuffle=True)
print(xtrain.shape, ytrain.shape)
print(xtest.shape, ytest.shape)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)

# %%
pred = model.predict(xtest)
